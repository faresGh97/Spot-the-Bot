# %%
import numpy as np
import json
import pandas as pd
from tqdm import tqdm

# %%
corpus_path = './Thai_corpus.txt'

# %%
with open('Thai_WordVectorDict_CBOW100.json', encoding='utf-8') as f:
    CBOW_dic = json.load(f)
#print(CBOW_dic)

# %%
with open('Thai_WordVectorDict_SVD100.json', encoding='utf-8') as f:
    SVD_dic = json.load(f)
#print(SVD_dic)

# %%
def convert_text_to_vector(text, dictionary, n, m):
    
  #split the text into words
  print (text)
  text = str(text).strip().split()
  
  #It is the list for all the vectors in text
  text_vectors = []
  text_words = []

  #inspect all n-grams in the text
  for i in range(len(text) - n + 1):
        #The list of vectors for words in the n-gram
        gram_vec = []
        words = []
        #Let's look into every word of the n-gram
        for word in text[i:i+n]:
            #If current word is not in dictionary, we skip this n-gram 
            if word not in dictionary:
                gram_vec = []
                break
            vec_ = dictionary[word][:m]
            gram_vec.append(vec_)
            words.append(word)
        
      #If the list of vectors is not correct, we skip the n-gram
        if len(gram_vec) != n or len(gram_vec[-1]) != m:
            continue
        text_vectors.append(np.array(gram_vec).flatten())
        text_words.append(' '.join(words))
  text_dict = dict(zip(text_words, text_vectors))
  return text_dict

# %%
def vectorize_corpus_with_ngrams(corpus_path: str,
                                   separator: str,
                                   word_vector_dict: dict, n : int , m : int  ) -> np.ndarray:
    colnames=['Text Title', 'X', 'Y', 'Text'] 
    df_corpus = pd.read_csv(corpus_path, delimiter= "$", names =colnames, header=None)[['Text Title', 'Text']]
    corpus = df_corpus['Text'].tolist()
    #print (corpus)
    vectorized_corpus = list()
    for text_index, text in enumerate(tqdm(corpus)):
        vectorized_text = dict()
        if not text:
            continue
        
        vectorized_t = convert_text_to_vector(text, word_vector_dict,n,m)
        vectorized_text['document_index'] = text_index
        vectorized_text['vectorized_text'] = vectorized_t
        vectorized_corpus.append(vectorized_text)
    return np.array(vectorized_corpus, dtype=object)

# %%
#How long is the n-gram
n = 1
#How long is a vector for every word
m = 100

# %%
text = "test_corpus.txt"

# %%
colnames=['Text Title', 'X', 'Y', 'Text']

# %%
df_corpus = pd.read_csv(text, delimiter= "$", names =colnames, header=None)[['Text Title', 'Text']]

# %%
df_corpus
# Out:
#                                         Text Title  \
# 0                                              NaN
# 1  เทศน์เรื่องมังสวิรัติโดยหลวงตามหาบัวญาณสัมปันโน
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#                                                 Text
# 0  ชุดิจรรมแทัษะภาษา อังฤษเพื่อาร สื่อสาร ล่ม สาร...
# 1  เทศน์ เรื่อง มังสวิรัติ หลวง หาบัว เบื้อ หา จา...
# 2                                                NaN
# 3  สเตเสวนาคสรูป ผลารถำเนิน งานาร เวที่ เสวนา นัค...
# 4  เบษายน ล่งทางารเินใล้ ที่มั ด้ย่น หข่าวคราว มิ...

# %%
df_corpus =df_corpus.dropna(subset=['Text'])
df_corpus
# Out:
#                                         Text Title  \
# 0                                              NaN
# 1  เทศน์เรื่องมังสวิรัติโดยหลวงตามหาบัวญาณสัมปันโน
# 3                                              NaN
# 4                                              NaN
#
#                                                 Text
# 0  ชุดิจรรมแทัษะภาษา อังฤษเพื่อาร สื่อสาร ล่ม สาร...
# 1  เทศน์ เรื่อง มังสวิรัติ หลวง หาบัว เบื้อ หา จา...
# 3  สเตเสวนาคสรูป ผลารถำเนิน งานาร เวที่ เสวนา นัค...
# 4  เบษายน ล่งทางารเินใล้ ที่มั ด้ย่น หข่าวคราว มิ...

# %%
vectorized_corpus = vectorize_corpus_with_ngrams(text,
                                               ' ',
                                               SVD_dic,n,int(m/n))
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# ชุดิจรรมแทัษะภาษา อังฤษเพื่อาร สื่อสาร ล่ม สาระารเรียนร้ภาษา ประเทศ นางสาวนันทนิตย์นิโรธสั๓ ๓า ตาแหนงครวทยชิา นะ คร ขานาณาร รงเรียน ศาลเจ้าห้าวนุคูลวิทยาสำนังานเขตบางขุนเทียนรุง เทพมหานคร คานา ชุดิจรรมฟิทัษะภาษา อังฤษเพื่อารสื่อสาร ลุ่มสาระารเรียนรู้ ภาษา ประเทศ นัเรียน ชั้น ประถม ศึษา ปี จัดทำ สื่อารเรียนรู้ประอบารเรียนาร สอน วิชา ภาษา อังฤษ ประสบ สำเร็จ ยิ่ง ผู้ เรียน สามารถ รู้ สามารถ ประยุต์ ใช้ เิด ประโยชน์ ชีวิต ประจำ ชุดิจรรมฟิทัษะภาษา อังฤษเพื่อารสื่อสาร ลุ่มสาระารเรียนรู้ ภาษา ประเทศ ภาษา อังฤษ นัเรียน ชั้น ประถม ศึษา ปี จัดทำ ทั้งหมด เล่ม เล่ม เป็นชุดิจรรมที่ บเโ๓ นัเรียน เรียนรู้ ศัพท์ารสนทนาร อ่าน และารเขียน เี่ยวับิจรรมยาม ว่างมีารบูรณารทัษะ คือารฟ้ง พูด อ่าน เขียน สัมพันธั์น ลำดับ เรียนรู้ จา ใบ รู้ ชุดิจรรม ประอบ คู่มือ นัเรียน ทดสอ บ่อน เรียน และิจรรมในชุดิจรรมนัเรียน เรียนรู้ จน ครบ จำนวน ลำดับ ของิจรรมแต่ ละิจรรมทำ นัเรียน เข้าใจ เนื้อหา ดี หวัง ยิ่ง ชุดิจรรมฟิทัษะภาษา อังฤษ เล่ม ประโยชน์ ครู ผู้ สอน นัเรียน ร่วมมือ ในารจัดิจรรมารเรียนาร สอน แนวทาง ชองิจรรม พัฒนา นันทนิตย์นิโรธ สัญญา ตำแหน่ง ครูวิทยฐานะ ครูชำนาญาร โรงเรียนศาลเจ้าห้าวนุูลวิทยา บเโาทเ สาร บัญ เรื่อง หน้า คำนำ สารบัญข คำ แนะนำ ในาร ใช้ ชุดิจรรมสำหรับ นัเรียนค ทดสอ บ่อนเรียนบหา บเโ๓ เบรเทรู ล๐ รู ญะ วะลเวนลเรวลบรูน เโรรเทเว๒ร ะละแทรู ะพํรู ทดสอบ เรียนบเโ๓ เฉลยชุดิจรรมที่ บเ๓๓ ตาราง บัน ทึ คะแนน บเทโเาข คำ แนะนำ ในาร ใช้ ชุดิจรรมสำหรับ นัเรียน ชุดิจรรมผืทัษะภาษา อังฤษเพื่อารสื่อสาร ลุ่มสาระารเรียนรู้ ภาษา ประเทศ นัเรียน ชั้น ประถม ศึษา ปี ชุด เป็นชุดิจรรม ใช้ ประอบารเรียน เป็นชุดิจรรมที่ นัเรียน สามารถ ศึษา เช้าใจ นัเรียน อ่าน คำ แนะนำ ปฏิบัติ จรรม ชั้น ตอน ของิจรรม สามารถ สอบถาม ประเด็น สงสัย จา ครู ผู้ สอน ตรง นัเรียน รู้ เช้าใจ คำ แนะนำ ซัดเจน ปฏิบัติ ชั้น ตอน คำ แนะนำ นัเรียน ชุดิจรรมฝืทัษะภาษา อังฤษเพื่อาร สื่อสาร เวลา ชั่วโมง จุดประสงค์ารเรียนรู้ นัเรียนเรียน จบ ชุด นัเรียน สามารถ ฟ้ง เสียง อ่าน ออ เสียง บอความหมาย คำ ศัพท์ เรียน ใช้ ประโยค สนทนา เี่ยวับิจรรมยาม ว่าง ใช้ โครงสร้าง ประโยคโทเ๐ทเษวนรท ถู อ่าน เนื้อ เรื่อง สามารถ ตอบ คำ ถาม เขียน บรรยายิจรรม ยาม ว่าง บุคคล ใล้ตัว ิจรรมที่ นัเรียน ปฏิบัติ ตั้งใจ อ่าน ใบ รู้ ใบิจรรม ทดสอ บ่อนเรียน ทำิจรรมทุิจรรม ครบถ้วน สมบูรณ์ ทดสอบ เรียน นัเรียน สื่อ อุปรณ์ พลโทาน เว เพลง พเาลป๐นป บทแาเค ะลเวนลเ ะลเวน ใบ รู้ เโด่ร ะรวลเปน ใบ รู้ ะร โวนวนรไท ใบ รู้ เโดํรที่ ะเไลแ ะพิเ ะป เะร าร ประเมิน ผลารเรียนนัเรียนทำิจรรม ครูำ หนด ครู ผู้ สอน ประเมิน จาร ทดสอ บ่อน เรียน ารประเมิน จา ผลงาน นัเรียนในารปฏิบัติ จรรม ารประเมิน จาร สังเตพฤติรรมนัเรียน าร ประเมิน จาร สังเตคุณลัษณะ อันพึง ประสงค์ บเหโเง บแะโท ทดสอ บ่อนเรียนบใโธ ชั้น ประถม ศึษา ปี ลุ่มสาระารเรียนรู้ ภาษา ประเทศ คำ ชี้แจง ทดสอบ จำนวน ข้อ คะแนน คะแนน เวลา นาที นัเรียน เครื่องหมาย ข้อ ขคหรือง ลู เพียง ข้อ แรทลทปะาเวเะนล เว ๐ลเาเวเะนลทปเทเาเวลทแ ลลเปํเวะลผลเวเลน ะรผ เทป พละเา บแหโเา บเาเวฤน ๐ปาทพร๐พ ลรทเทรูเวล๓รรูบรเรู เาลลโนป รู ดเโลพลเวะนโ เวล๓วเโลพล เวปบโ บล๓ปลพรูลวะน ล๓แทไรูบเโลพลว๐ ลเปาเวลรรลลง่ลรพโปานรป๐ร าล๓ เลเา๐ เปาลลเารนเรเาแล ทวเปาเวเฟรรเทเทรูรลเวลน๐ เลแทารเวลเพโรเทราเรท่ท่เท่รู๓ ลปลบเโลแรูลเว๐ ๓ลปเลรอาลเวลเพเาเาเรูปม่าเรรเวรูเาเาล๓แเรทเาล เวเวปลรล๐ ลปปาโเา๐ ๐เปาลโ บแเา พเาลเโเาอฝอรู แอเรแรู เวแ
# nan
# สเตเสวนาคสรูป ผลารถำเนิน งานาร เวที่ เสวนา นัคิดดิจิทัล เล่ม สสสโงาน องทุน สนับสนุน ารสร้างเสริม สุขภาพ โคแฟค เิด แรง บันดาลใจจาร ตัว ภาค ประชาสังคม ไต้หวันทีเชือเรือง พลัง ภาค พลเมืองในาร รับมือับ มืด ข้อมูล รรณาธิาร ทำงา นับ อาสาสมัคร เพื่อร อเท็จจริง แสดง ร่ว มัน อี ข่าว ทีม ลันรอง่อน เผยแพร่ สือ สังคม ออนไลน์ เชื่อ มัน ในาร ข้อมูล เว็บไซต์ ช่วย ตรวจสอบ ข้อ เท็จจริง ขยาย งาน สู่า คโนโลยี ภาค พลเมืองร่วมั เพียง ชุมชนนัวิชาร นัขับเคลือนงานด้า ช่วยัน ตรวจสอบ ข้อมูล ข่าว ลวง ข่าว จริง ข้อมูล ทิถู ออ สู่ สังคม ไปนวัตรรมโคแฟคนี่ ๑รูเรื่๑ฉรรุขู่ช่ยมม ถือ ภา ริจาร ปฏิรูปสือ ยุค ดิจิ ทัลทิลับ สร้าง เข้มแข็ง ภา พื้นที่ ถเถียง เชิง นโยบาย สาธารณะ แลเ พัฒนา แนว ทางา รำับดูแล เทคโนโลยี้าวระโดดและารพัฒนา นสือ สาร มวล ชนเ าวสาร ด้วยาร พืนทึลาง ทุฝ่าย ช่ว ยัน ค้นหา ข้อ เท็จจริง ฝ่าย ใด ฝ้ รู้ จริง ข้อ เท็จจริง เปลี่ยนแปลง ตา มาล เวลา เหตุปัจจัย บงาน เชิงข่าว ต้าน วารสารศาสติง ไลน์ แชทบอทโปรแรมพูดาค พลเมืองจารนำแอ ่านันหา รงม เละสือ มวล ชน อี ปพลิเคชัน ไลน์ แชทบอท ฐานร สร้าง ชุมชน ผู้ ตรวจสอบ ข้อมูล ทุ คน ทุเ ร้อมับารพัฒนานวัตรรมโคแฟคโครงาร ดำเนินารจั้ปลี คพลเมือง แดเวที เสวนานัคิยน คิดเห็น ยืน ซึงาร เว คุย อัตโนมัติ ที ทุคน ายหนง เพยง มีาร ประสาน งาน สร้าง ร่วมมือ จน สู่ โค แฟค ประเทศไทย มีาร ใช้ ร์ยป ๐น ไน มีอง องข่าว พืนทึลาง ทุ คน แล เปลี่ยน โต้แย้ง ศทุ วัย ทิ ทจริงดดิจิทัล ระดม สมอง แต่ละ ครัง เป้าหมาย ข้อ เสนอแนะ แนวทาง นโยบาย สาธารณะ ในารำับ รูปธรรม สำเร็จ เทคโนโลยีดิจิทัลและารสือ สาร สู่ แนว เข้มแข็ง พลเมือง ในาร รับมือ โลออนไลน์ างารพัฒนา ยืน ส่งเสริม ารสาน เสวนานัคิดดิจิทัล ถู ขึ่น สิน ระยะ เวลาปี เต็ม เดือน รฎาคม พศ เ
ดินทาง ธนาคารแต็่ รอารตรวจสอบ ดำเนินารอี ขั้นตอน จจุบันนี้าครัฐ ระบวนาร แจ้ง อนไลน์ ออ หมาย อายัด บัญชี ทัน บัญชีม้าับารจัดาร ปัจจุบัน หรือาร ใช้ บัญชี ธนาคาร ฟลแเของ ผู้ อื่น ใช้ ในาร ทุจริต แบ่ง ออ ประเภท ม้า สมัครใจ คือารหาย บัญชี ธนาคาร ฟลแเให้ ผู้ อื่น มีาร ข้อมูล บัญชี หาย ใหั้บ ลุ่ม มิจฉาชีพ ม้า ตั้งใจ ถู สวมรอย ถู หลอ เอา ข้อมูล ใช้ ในาร บัญชี ธนาคาร พลแเพื่อ เอา ใช้ ในาร ธุรรรม ทุจริต ฟอ พิน่อาร ร้าย ตัวอย่าง หขบวนารริบ จ้าง บัญชี ม้า ออนไลน์ เจ้าของ บัญชีสแนม ทิ โทรศัพท์ หอง มิจฉาซ่พ ส่งโธ เจ้าหองบัญชี รอ จ่ง มิจฉาซีพ สังให้ แม่ค้า คนลาง หา บัญชี ธนาคาร สามารถ ออนไลน์ ห้อ มูล บัญ ชืีออนไลน์ บัตร ประชาชน ผู บัญชีับ เบอร์โทรศัพท์๊ ตน เองับ คน หาย เนมื่อ บัญชี เสร็จ รบจาล ล่ม คนหายบ ปัญชี เแม่ ค้า คน ลาง ประาศ หา คน ทิพร้อมน ยืนยัน ตัว ตน ลุ่มซื่อ ขาย บัญชี นึ ปัญหา แนวทาง แ้ อนาคต ปัญหา ปัจจุบัน แนวทาง แ้ไห มีฎหมาย รองรับ ชัดเจน ในาร เอาพ ผิด ตรงับ คน จ้าง บัญชี มอบ บัญชี ตน มิจฉาชีพ ใช้ งาน สุจิต ระบวนาร ข้อมูล ตรวจสอบ แจ้ง อายัด บัญชี ใช้ ในาร ฉ้อโง ล่าช้า ทันารณ์ เนื่องจา สถาบันารผิน ห้อ จำัดในาร ติดตาม ธุรรรม ปัญหาร ส่งห้อ มูล ห้าม หน่วย งาน และาร ปฏิบัติตา มาร ดูแล ข้อมูล บุคคล ารทำ ระบวนารรู้ จัลู ค้า แสดง ตน พิสูจน์ ทราบ ตัวตน หองผู้ เปิดบ ปัญซี หลัเณฑ์ ช่องโหว่ รณี มีารหาย บัญชี หอง ตน ใหั้บ ผู้ อื่น เนื่องจาเป็นาร ยินยอมหอง เจ้าหของบัญชี สำนังานป้องัน ปราบปรามาร ฟอพผินปปง ระหว่างารแ้ พรบเพื่อำ หนด ให้ารริบ จ้าง บัญชี ผู้ จิด หา ผิด ฎหมาย เและ หารือ แนว ทางาร ศูนย์ลางพเรใหั้บ สถาบัน ารผิน ผู้ ประอบรุริจ๑ ปรับปรุง ฐูป ช่องทาง ทั้งำ หนด  ...

# %%
vectorized_corpus = vectorize_corpus_with_ngrams(corpus_path,
                                               ' ',
                                               CBOW_dic,n,int(m/n))

# %%
np.save("Thai_vectorized_corpus_CBOW_1gram_6", vectorized_corpus)

# %%
np.save("Thai_vectorized_corpus_SVD_1gram_6", vectorized_corpus)
